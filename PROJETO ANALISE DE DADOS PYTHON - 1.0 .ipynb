# %%
import os
import pandas as pd

lista_arquivo = os.listdir("/content/drive/MyDrive/Curso basico de python/Vendas")
display(arquivo)

tabela_total = pd.DataFrame()
# Passo 2 - importa as base de dados de vendas

for arquivo in lista_arquivo:

 # se tem "Vendas" no nome do arquivo, então

  if "Vendas"in arquivo:
  # importa arquivos
    tabela = pd.read_csv(f"/content/drive/MyDrive/Curso basico de python/Vendas/{arquivo}")
    tabela_total = tabela_total.append(tabela)

# Passo 3 - tratar / compilar as base de dados
display(tabela_total )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-3e17016b36c5> in <cell line: 4>()
#       2 import pandas as pd
#       3
# ----> 4 lista_arquivo = os.listdir("/content/drive/MyDrive/Curso basico de python/Vendas")
#       5 display(arquivo)
#       6
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Curso basico de python/Vendas'

# %%
tabela_produtos = tabela_total.groupby("Produto").sum()
tabela_produtos = tabela_produtos[["Quantidade Vendida", "Preco Unitario" ]].sort_values(by="Quantidade Vendida", ascending= False)
display(tabela_produtos)
# Out:
#             Quantidade Vendida  Preco Unitario
# Produto
# iPhone                    8974        15778100
# Televisão                 5931         4905000
# Notebook                  3249         3717000
# Android                   3183         3631200
# SmartWatch                2980         1393000
# Tablet                    2921         1556800
# Câmera                    2805         2020200

# %%
# Passo 5 - Calcular o produto que mais faturou (em faturamento)
tabela_total["Faturamento"] = tabela_total["Quantidade Vendida"] * tabela_total["Preco Unitario"]

tabela_faturamento = tabela_total.groupby("Produto").sum()
tabela_faturamento = tabela_faturamento[["Faturamento"]].sort_values(by="Faturamento", ascending= False)
display(tabela_faturamento)
# Out:
#             Faturamento
# Produto
# iPhone         47562200
# Televisão      14827500
# Notebook       11371500
# Android        10822200
# Câmera          5890500
# Tablet          4673600
# SmartWatch      4172000

# %%
# Passo 6 - Calcular a Loja/Cidade quem mais vendeu (em faturamento) - criar uma grafico/dashbord
tabela_lojas = tabela_total.groupby("Loja").sum()
tabela_lojas = tabela_lojas[["Faturamento"]]
display(tabela_lojas)
# Out:
#                 Faturamento
# Loja
# Belo Horizonte      6480300
# Curitiba            7060500
# Fortaleza          14087900
# Goiás               7441800
# Porto Alegre        6868600
# Recife              7303000
# Rio de Janeiro     14867800
# Salvador           13111300
# São Paulo          22098300

# %%
# Passo 7 grafico dashbord
import plotly.express as px

grafico = px.bar(tabela_lojas, x= tabela_lojas.index, y= "Faturamento")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
